"TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN MAJALENGKA", 546.54, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN SUMEDANG", 707.75, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN INDRAMAYU", 792.48, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN SUBANG", 739.6, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN PURWAKARTA", 239.72, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN KARAWANG", 614.61, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN BEKASI", 1193.76, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN BANDUNG BARAT", 201.09, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN PANGANDARAN", 46.62, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA BOGOR", 719.72, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA SUKABUMI", 232.06, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA BANDUNG", 1529.04, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA CIREBON", 229.75, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA BEKASI", 1500.77, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA DEPOK", 1418.87, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA CIMAHI", 193.36, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA TASIKMALAYA", 295.87, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA BANJAR", 60.29, "TON PER HARI", 2021)   
]

# No. 1
df = pd.DataFrame(data, columns = ["Provinsi", "Kabupaten/Kota", "Jumlah Produksi Sampah", "Satuan", "Tahun"])
df
# Out:
#        Provinsi      Kabupaten/Kota  Jumlah Produksi Sampah        Satuan  \
# 0    JAWA BARAT     KABUPATEN BOGOR                 1511.15  TON PER HARI
# 1    JAWA BARAT  KABUPATEN SUKABUMI                  419.01  TON PER HARI
# 2    JAWA BARAT   KABUPATEN CIANJUR                  981.41  TON PER HARI
# 3    JAWA BARAT   KABUPATEN BANDUNG               189594.00  TON PER HARI
# 4    JAWA BARAT     KABUPATEN GARUT                  464.74  TON PER HARI
# ..          ...                 ...                     ...           ...
# 184  JAWA BARAT         KOTA BEKASI                 1500.77  TON PER HARI
# 185  JAWA BARAT          KOTA DEPOK                 1418.87  TON PER HARI
# 186  JAWA BARAT         KOTA CIMAHI                  193.36  TON PER HARI
# 187  JAWA BARAT    KOTA TASIKMALAYA                  295.87  TON PER HARI
# 188  JAWA BARAT         KOTA BANJAR                   60.29  TON PER HARI
#
#      Tahun
# 0     2015
# 1     2015
# 2     2015
# 3     2015
# 4     2015
# ...

# %%
# Menghitung total produksi sampah untuk tahun 2015
total_2015 = df[df["Tahun"] == 2015]["Jumlah Produksi Sampah"].sum()

print(f"Total produksi sampah di seluruh Kabupaten/Kota Jawa Barat pada tahun 2015 adalah {total_2015} ton per hari.")
# Out:
# Total produksi sampah di seluruh Kabupaten/Kota Jawa Barat pada tahun 2015 adalah 208667.32999999996 ton per hari.

# %%
# No. 2 (Total produksi sampah seluruh Kabupaten/Kota di Jawa Barat tahun 2021)

import pandas as pd

data = [
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN BOGOR", "Jumlah Produksi Sampah": 971.59, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN SUKABUMI", "Jumlah Produksi Sampah": 356.02, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN CIANJUR", "Jumlah Produksi Sampah": 355.69, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN BANDUNG", "Jumlah Produksi Sampah": 1489.04, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN GARUT", "Jumlah Produksi Sampah": 321.17, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN TASIKMALAYA", "Jumlah Produksi Sampah": 172.26, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN CIAMIS", "Jumlah Produksi Sampah": 614.61, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN KUNINGAN", "Jumlah Produksi Sampah":  405.76, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN CIREBON", "Jumlah Produksi Sampah": 242.52, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN MAJALENGKA", "Jumlah Produksi Sampah": 546.54, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN SUMEDANG", "Jumlah Produksi Sampah": 707.75, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN INDRAMAYU", "Jumlah Produksi Sampah": 792.48, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN SUBANG", "Jumlah Produksi Sampah": 739.6, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN PURWAKARTA", "Jumlah Produksi Sampah": 239.72, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN KARAWANG", "Jumlah Produksi Sampah": 614.61, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN BEKASI", "Jumlah Produksi Sampah": 1193.76, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN BANDUNG BARAT", "Jumlah Produksi Sampah": 201.09, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KABUPATEN PANGANDARAN", "Jumlah Produksi Sampah": 46.62, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KOTA BOGOR", "Jumlah Produksi Sampah": 719.72, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KOTA SUKABUMI", "Jumlah Produksi Sampah": 232.06, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KOTA BANDUNG", "Jumlah Produksi Sampah": 1529.04, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KOTA CIREBON", "Jumlah Produksi Sampah": 229.75, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KOTA BEKASI", "Jumlah Produksi Sampah": 1500.77, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KOTA DEPOK", "Jumlah Produksi Sampah": 1418.87, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KOTA CIMAHI", "Jumlah Produksi Sampah": 193.36, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KOTA TASIKMALAYA", "Jumlah Produksi Sampah": 295.87, "Satuan": "Ton per Hari", "Tahun": 2021},
    {"Provinsi": "JAWA BARAT", "Kabupaten/Kota": "KOTA BANJAR", "Jumlah Produksi Sampah": 60.29, "Satuan": "Ton per Hari", "Tahun": 2021}
]

# Membuat DataFrame
df = pd.DataFrame(data)

# Variabel untuk menyimpan total produksi sampah
total_produksi = 0

# Menggunakan iterrows untuk menghitung total produksi di Jawa Barat tahun 2021
for index, row in df.iterrows():
    if row["Provinsi"] == "JAWA BARAT" and row["Tahun"] == 2021:
        total_produksi += row["Jumlah Produksi Sampah"]

# Menampilkan hasil
print(f"Total produksi sampah di seluruh Kabupaten/Kota di Jawa Barat pada tahun 2021: {total_produksi:.2f} Ton per Hari")
# Out:
# Total produksi sampah di seluruh Kabupaten/Kota di Jawa Barat pada tahun 2021: 16190.56 Ton per Hari

# %%
# No. 3 Menjumlahkan Data Per Tahun

import pandas as pd

columns = ["Provinsi", "Kota/Kabupaten", "Nilai", "Satuan", "Tahun"]
data = [
    ("JAWA BARAT", "KABUPATEN BOGOR", 1511.15, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN SUKABUMI", 419.01, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN CIANJUR", 981.41, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN BANDUNG", 189594, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN GARUT", 464.74, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN TASIKMALAYA", 464.52, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN CIAMIS", 260.91, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN KUNINGAN", 251.7, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN CIREBON", 465.75, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN MAJALENGKA", 254.63, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN SUMEDANG", 237.96, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN INDRAMAYU", 613.18, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN SUBANG", 487.26, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN PURWAKARTA", 308.96, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN KARAWANG", 869.86, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN BEKASI", 1228.6, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN BANDUNG BARAT", 616.08, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN PANGANDARAN", 185.83, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA BOGOR", 991.93, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA SUKABUMI", 309.91, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA BANDUNG", 2448.63, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA CIREBON", 304.15, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA BEKASI", 2387.08, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA DEPOK", 1844.3, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA CIMAHI", 563.21, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA TASIKMALAYA", 472.36, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA BANJAR", 130.21, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN BOGOR", 1511.15, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN SUKABUMI", 419.01, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN CIANJUR", 981.41, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN BANDUNG", 1895.94, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN GARUT", 464.74, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN TASIKMALAYA", 464.52, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN CIAMIS", 260.91, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN KUNINGAN", 251.7, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN CIREBON", 465.75, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN MAJALENGKA", 254.63, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN SUMEDANG", 237.96, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN INDRAMAYU", 613.18, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN SUBANG", 487.26, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN PURWAKARTA", 308.96, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN KARAWANG", 869.86, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN BEKASI", 1228.6, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN BANDUNG BARAT", 616.08, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN PANNGANDARAN", 185.83, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN BOGOR", 991.93, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN SUKABUMI", 309.91, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN BANDUNG", 32448.63, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN CIREBON", 304.15, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN BEKASI", 2387.08, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN DEPOK", 1844.3, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN CIMAHI", 563.21, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN TASIKMALAYA", 472.36, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN BANJAR", 130.21, "TON PER HARI", 2016),
    ("JAWA BARAT", "KABUPATEN BOGOR", 1511.15, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN SUKABUMI", 419.01, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN CIANJUR", 981.41, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN BANDUNG", 1895.94, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN GARUT", 464.74, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN TASIKMALAYA", 464.52, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN CIAMIS", 260.91, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN KUNINGAN", 251.7, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN CIREBON", 465.75, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN MAJALENGKA", 254.63, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN SUMEDANG", 237.96, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN INDRAMAYU", 613.18, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN SUBANG", 487.26, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN PURWAKARTA", 308.96, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN KARAWANG", 869.86, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN BEKASI", 1228.6, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN BANDUNG BARAT", 616.08, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN PANGANDARAN", 185.83, "TON PER HARI", 2017),
    ("JAWA BARAT", "KOTA BOGOR", 991.93, "TON PER HARI", 2017),
    ("JAWA BARAT", "KOTA SUKABUMI", 309.91, "TON PER HARI", 2017),
    ("JAWA BARAT", "KOTA BANDUNG", 2448.63, "TON PER HARI", 2017),
    ("JAWA BARAT", "KOTA CIREBON", 304.15, "TON PER HARI", 2017),
    ("JAWA BARAT", "KOTA BEKASI", 2387.08, "TON PER HARI", 2017),
    ("JAWA BARAT", "KOTA DEPOK", 1844.3, "TON PER HARI", 2017),
    ("JAWA BARAT", "KOTA CIMAHI", 563.21, "TON PER HARI", 2017),
    ("JAWA BARAT", "KOTA TASIKMALAYA", 472.36, "TON PER HARI", 2017),
    ("JAWA BARAT", "KOTA BANJAR", 130.21, "TON PER HARI", 2017),
    ("JAWA BARAT", "KABUPATEN BOGOR", 1716.8, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN SUKABUMI", 415.5, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN CIANJUR", 965.19, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN BANDUNG", 2068.06, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN GARUT", 473.89, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN TASIKMALAYA", 458.45, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN CIAMIS", 263.01, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN KUNINGAN", 248.52, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN CIREBON", 466.25, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN MAJALENGKA", 249.26, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN SUMEDANG", 236.12, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN INDRAMAYU", 603.11, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN SUBANG", 498.7, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN PURWAKARTA", 323.87, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN KARAWANG", 896.85, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN BEKASI", 1600.71, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN BANDUNG BARAT", 663.54, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN PANGANDARAN", 171.21, "TON PER HARI", 2018),
    ("JAWA BARAT", "KOTA BOGOR", 1069.41, "TON PER HARI", 2018),
    ("JAWA BARAT", "KOTA SUKABUMI", 318.12, "TON PER HARI", 2018),
    ("JAWA BARAT", "KOTA BANDUNG", 2441.12, "TON PER HARI", 2018),
    ("JAWA BARAT", "KOTA CIREBON", 308.37, "TON PER HARI", 2018),
    ("JAWA BARAT", "KOTA BEKASI", 2858.6, "TON PER HARI", 2018),
    ("JAWA BARAT", "KOTA DEPOK", 2272.07, "TON PER HARI", 2018),
    ("JAWA BARAT", "KOTA CIMAHI", 592.62, "TON PER HARI", 2018),
    ("JAWA BARAT", "KOTA TASIKMALAYA", 465.23, "TON PER HARI", 2018),
    ("JAWA BARAT", "KOTA BANJAR", 128.34, "TON PER HARI", 2018),
    ("JAWA BARAT", "KABUPATEN BOGOR", 2914.65, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN SUKABUMI", 1003.64, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN CIANJUR", 1115.81, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN BANDUNG", 1334.12, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN GARUT", 1144.01, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN TASIKMALAYA", 753.06, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN CIAMIS", 560.57, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN KUNINGAN", 537.25, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN CIREBON", 3.15, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN MAJALENGKA", 515.7, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN SUMEDANG", 436.96, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN INDRAMAYU", 1071.05, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN SUBANG", 1012.45, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN PURWAKARTA", 384.43, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN KARAWANG", 934.4, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN BEKASI", 2590, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN BANDUNG BARAT", 1124.5, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN PANGANDARAN", 250.23, "TON PER HARI", 2019),
    ("JAWA BARAT", "KOTA BOGOR", 620.55, "TON PER HARI", 2019),
    ("JAWA BARAT", "KOTA SUKABUMI", 172.82, "TON PER HARI", 2019),
    ("JAWA BARAT", "KOTA BANDUNG", 1575.73, "TON PER HARI", 2019),
    ("JAWA BARAT", "KOTA CIREBON", 245, "TON PER HARI", 2019),
    ("JAWA BARAT", "KOTA BEKASI", 2060.7, "TON PER HARI", 2019),
    ("JAWA BARAT", "KOTA DEPOK", 1469.77, "TON PER HARI", 2019),
    ("JAWA BARAT", "KOTA CIMAHI", 267.74, "TON PER HARI", 2019),
    ("JAWA BARAT", "KOTA TASIKMALAYA", 291.6, "TON PER HARI", 2019),
    ("JAWA BARAT", "KOTA BANJAR", 100.67, "TON PER HARI", 2019),
    ("JAWA BARAT", "KABUPATEN BOGOR", 2977, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN SUKABUMI", 1006, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN CIANJUR", 1117, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN BANDUNG", 1355, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN GARUT", 1151, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN TASIKMALAYA", 754, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN CIAMIS", 564, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN KUNINGAN", 540, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN CIREBON", 1096, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN MAJALENGKA", 518, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN SUMEDANG", 438, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN INDRAMAYU", 1077, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN SUBANG", 1023, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN PURWAKARTA", 388, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN KARAWANG", 942, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN BEKASI", 2258, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN BANDUNG BARAT", 1135, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN PANGANDARAN", 252, "TON PER HARI", 2020),
    ("JAWA BARAT", "KOTA BOGOR", 567, "TON PER HARI", 2020),
    ("JAWA BARAT", "KOTA SUKABUMI", 181, "TON PER HARI", 2020),
    ("JAWA BARAT", "KOTA BANDUNG", 1630, "TON PER HARI", 2020),
    ("JAWA BARAT", "KOTA CIREBON", 192, "TON PER HARI", 2020),
    ("JAWA BARAT", "KOTA BEKASI", 1923, "TON PER HARI", 2020),
    ("JAWA BARAT", "KOTA DEPOK", 1516, "TON PER HARI", 2020),
    ("JAWA BARAT", "KOTA CIMAHI", 369, "TON PER HARI", 2020),
    ("JAWA BARAT", "KOTA TASIKMALAYA", 285, "TON PER HARI", 2020),
    ("JAWA BARAT", "KOTA BANJAR", 79, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN BOGOR", 971.59, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN SUKABUMI", 356.02, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN CIANJUR", 355.69, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN BANDUNG", 1489.04, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN GARUT", 321.17, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN TASIKMALAYA", 172.26, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN CIAMIS", 159.41, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN KUNINGAN", 405.76, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN CIREBON", 242.52, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN MAJALENGKA", 546.54, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN SUMEDANG", 707.75, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN INDRAMAYU", 792.48, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN SUBANG", 739.6, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN PURWAKARTA", 239.72, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN KARAWANG", 614.61, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN BEKASI", 1193.76, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN BANDUNG BARAT", 201.09, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN PANGANDARAN", 46.62, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA BOGOR", 719.72, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA SUKABUMI", 232.06, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA BANDUNG", 1529.04, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA CIREBON", 229.75, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA BEKASI", 1500.77, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA DEPOK", 1418.87, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA CIMAHI", 193.36, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA TASIKMALAYA", 295.87, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA BANJAR", 60.29, "TON PER HARI", 2021)   
]

df = pd.DataFrame(data, columns=columns)

jumlah_pertahun = {}
for _, row in df.iterrows():
    tahun = row["Tahun"]
    nilai = row["Nilai"]
    if tahun in jumlah_pertahun:
        jumlah_pertahun[tahun] += nilai
    else:
        jumlah_pertahun[tahun] = nilai
        
print("Jumlah sampah per tahun:")
for tahun, total in jumlah_pertahun.items():
    print(f"Tahun {tahun}: {total:.3f} Ton")
# Out:
# Jumlah sampah per tahun:
# Tahun 2015: 208667.330 Ton
# Tahun 2016: 50969.270 Ton
# Tahun 2017: 20969.270 Ton
# Tahun 2018: 22772.920 Ton
# Tahun 2019: 24490.560 Ton
# Tahun 2020: 25333.000 Ton
# Tahun 2021: 15735.360 Ton

# %%
# No. 4 Menjumlahkan Data per Kota/Kabupaten pada Masing-masing Tahun

import pandas as pd

columns = ["Provinsi", "Kota/Kabupaten", "Nilai", "Satuan", "Tahun"]
data = [
    ("JAWA BARAT", "KABUPATEN BOGOR", 1511.15, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN SUKABUMI", 419.01, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN CIANJUR", 981.41, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN BANDUNG", 189594, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN GARUT", 464.74, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN TASIKMALAYA", 464.52, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN CIAMIS", 260.91, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN KUNINGAN", 251.7, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN CIREBON", 465.75, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN MAJALENGKA", 254.63, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN SUMEDANG", 237.96, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN INDRAMAYU", 613.18, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN SUBANG", 487.26, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN PURWAKARTA", 308.96, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN KARAWANG", 869.86, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN BEKASI", 1228.6, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN BANDUNG BARAT", 616.08, "TON PER HARI", 2015),
    ("JAWA BARAT", "KABUPATEN PANGANDARAN", 185.83, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA BOGOR", 991.93, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA SUKABUMI", 309.91, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA BANDUNG", 2448.63, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA CIREBON", 304.15, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOTA BEKASI", 2387.08, "TON PER HARI", 2015),
    ("JAWA BARAT", "KOT
"TON PER HARI", 2020),
    ("JAWA BARAT", "KOTA TASIKMALAYA", 285, "TON PER HARI", 2020),
    ("JAWA BARAT", "KOTA BANJAR", 79, "TON PER HARI", 2020),
    ("JAWA BARAT", "KABUPATEN BOGOR", 971.59, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN SUKABUMI", 356.02, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN CIANJUR", 355.69, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN BANDUNG", 1489.04, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN GARUT", 321.17, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN TASIKMALAYA", 172.26, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN CIAMIS", 159.41, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN KUNINGAN", 405.76, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN CIREBON", 242.52, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN MAJALENGKA", 546.54, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN SUMEDANG", 707.75, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN INDRAMAYU", 792.48, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN SUBANG", 739.6, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN PURWAKARTA", 239.72, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN KARAWANG", 614.61, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN BEKASI", 1193.76, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN BANDUNG BARAT", 201.09, "TON PER HARI", 2021),
    ("JAWA BARAT", "KABUPATEN PANGANDARAN", 46.62, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA BOGOR", 719.72, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA SUKABUMI", 232.06, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA BANDUNG", 1529.04, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA CIREBON", 229.75, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA BEKASI", 1500.77, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA DEPOK", 1418.87, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA CIMAHI", 193.36, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA TASIKMALAYA", 295.87, "TON PER HARI", 2021),
    ("JAWA BARAT", "KOTA BANJAR", 60.29, "TON PER HARI", 2021)   
]
df = pd.DataFrame(data, columns=columns)

jumlah_per_kota_pertahun = {}
for _, row in df.iterrows():
    kota = row["Kota/Kabupaten"]
    tahun = row["Tahun"]
    nilai = row["Nilai"]
    key = (kota, tahun)
    if key in jumlah_per_kota_pertahun:
        jumlah_per_kota_pertahun[key] += nilai
    else:
        jumlah_per_kota_pertahun[key] = nilai

print("\nJumlah Produksi Sampah per Kabupaten/Kota per Tahun:")
for (kota, tahun), total in jumlah_per_kota_pertahun.items():
    print(f"{kota}, Tahun {tahun}: {total:.2f} Ton")
# Out:
# Jumlah Produksi Sampah per Kabupaten/Kota per Tahun:
# KABUPATEN BOGOR, Tahun 2015: 1511.15 Ton
# KABUPATEN SUKABUMI, Tahun 2015: 419.01 Ton
# KABUPATEN CIANJUR, Tahun 2015: 981.41 Ton
# KABUPATEN BANDUNG, Tahun 2015: 189594.00 Ton
# KABUPATEN GARUT, Tahun 2015: 464.74 Ton
# KABUPATEN TASIKMALAYA, Tahun 2015: 464.52 Ton
# KABUPATEN CIAMIS, Tahun 2015: 260.91 Ton
# KABUPATEN KUNINGAN, Tahun 2015: 251.70 Ton
# KABUPATEN CIREBON, Tahun 2015: 465.75 Ton
# KABUPATEN MAJALENGKA, Tahun 2015: 254.63 Ton
# KABUPATEN SUMEDANG, Tahun 2015: 237.96 Ton
# KABUPATEN INDRAMAYU, Tahun 2015: 613.18 Ton
# KABUPATEN SUBANG, Tahun 2015: 487.26 Ton
# KABUPATEN PURWAKARTA, Tahun 2015: 308.96 Ton
# KABUPATEN KARAWANG, Tahun 2015: 869.86 Ton
# KABUPATEN BEKASI, Tahun 2015: 1228.60 Ton
# KABUPATEN BANDUNG BARAT, Tahun 2015: 616.08 Ton
# KABUPATEN PANGANDARAN, Tahun 2015: 185.83 Ton
# KOTA BOGOR, Tahun 2015: 991.93 Ton
# KOTA SUKABUMI, Tahun 2015: 309.91 Ton
# KOTA BANDUNG, Tahun 2015: 2448.63 Ton
# ...

# %%
df.to_csv('datasampah.csv', index=False)

# %%
df.to_excel('datasampah.xlsx', index=False)
